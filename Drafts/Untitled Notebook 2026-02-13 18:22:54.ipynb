# %%
# %sql
SELECT COUNT(DISTINCT most_recently_treated_hcp_hco_npi), COUNT(DISTINCT primary_hcp_hco_npi_2yr ), COUNT(DISTINCT latest_claim_hcp_hco_npi), COUNT(DISTINCT PATIENT_ID), COUNT(*) FROM com_edp_prd.cmpa_insights_internal_schema.patient360_master

# %%
# %sql
SELECT * FROM com_edp_prd.cmpa_insights_internal_schema.patient360_master
