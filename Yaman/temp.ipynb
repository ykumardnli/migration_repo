-- %%
select *
from com_edp_prd.com_raw.kom_providers
where ORGANIZATION_NAME ilike '%wake forest%'

-- %%
select corporate_name__v, npi_num__v
from com_edp_prd.com_raw.vod_hco
where corporate_name__v ilike '%atrium%' and corporate_name__v ilike '%wake forest%'

-- %%
select corporate_name__v, npi_num__v
from com_edp_prd.com_raw.vod_hco
where corporate_name__v ilike '%atrium mercy%'

-- %%
select *
from cmpa_insights_internal_schema.secondary_to_primary_npi
where secondary_npi in ('1295789907')
