-- %%
select crx_hcp_id, count(distinct hcp_npi)
from com_edp_prd.com_raw.crx_hcps
group by 1 
-- having count(distinct hcp_npi) > 1
order by 2 desc

-- %%
select a.*, b.hcp_npi, b.hcp_first_name, b.hcp_last_name, b.hcp_dea, b.`hcp_address:_zip/postal_code`, b.`hcp_address:_street_1`, b.`hcp_address:_street_2`, b.`hcp_address:_city`, b.`hcp_address:_state`
from com_edp_prd.com_raw.crx_dispenses as a
left join com_edp_prd.com_raw.crx_hcps as b on a.crx_hcp_id = b.crx_hcp_id

-- %%
select *
from com_raw.crx_hcps
