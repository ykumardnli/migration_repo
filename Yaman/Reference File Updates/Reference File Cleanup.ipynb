-- %%
select * from cmpa_insights_internal_schema.reference_file

-- %%
describe cmpa_insights_internal_schema.reference_file

-- %%
select * from cmpa_insights_internal_schema.zip_to_territory_mapping

-- %%
select distinct vid__v, npi_num__v, top_parent__v
from com_raw.vod_hco
where npi_num__v in ('1326332289', '1982609442', '1700026077')
