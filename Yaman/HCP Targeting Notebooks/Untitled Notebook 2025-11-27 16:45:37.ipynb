-- %%
select * from com_edp_prd.com_raw.vod_npi limit 4

-- %%
with t1 as (
  select a.*, b.vid__v as vid_2, b.corporate_name__v as name_2 
from com_raw.vod_npi as a 
left join com_raw.vod_hco as b on a.id = b.npi_num__v
where a.entity_type = 'HCO'
)
select * from t1 
-- where vid_2 is not null or name_2 is not null

-- %%
with t1 as (select a.vid__v as vid_1, b.npi_num__v as npi_1, b.corporate_name__v as name_1, 
a.id as npi_2
from com_edp_prd.com_raw.vod_npi as a
left join com_edp_prd.com_raw.vod_hco b on a.vid__v = b.vid__v
where a.entity_type = 'HCO'),
t2 as (select a.*, b.vid__v as vid_2, b.corporate_name__v as name_2
from t1 as a
left join com_raw.vod_hco as b on a.npi_2 = b.npi_num__v
-- where a.npi_num__v is not null or a.corporate_name__v is not null
)
select * 
from t2
-- where vid_2 is not null or name_2 is not null
order by vid_1, vid_2

-- %%
select distinct a.vid__v as vid_1, b.npi_num__v as npi_1, b.corporate_name__v as name_1, 
c.vid__v as vid_2, a.id as npi_2, c.corporate_name__v as name_2
from com_raw.vod_npi as a
join com_raw.vod_hco as b on a.vid__v = b.vid__v
join com_raw.vod_hco as c on a.id = c.npi_num__v
where a.entity_type = 'HCO'

-- %%
with t1 as (select distinct a.vid__v as vid_1, b.npi_num__v as npi_1, b.corporate_name__v as name_1, 
c.vid__v as vid_2, a.id as npi_2, c.corporate_name__v as name_2
from com_raw.vod_npi as a
join com_raw.vod_hco as b on a.vid__v = b.vid__v
join com_raw.vod_hco as c on a.id = c.npi_num__v
where a.entity_type = 'HCO')
select a.*
from t1 as a
where a.vid_1 in (select distinct vid__v from com_raw.vod_npi where entity_type = 'HCO' group by vid__v having count(distinct id) > 10)
order by a.vid_1

-- %%
select * from com_raw.vod_npi
where entity_type = 'HCO' and vid__v in ('242976927504139264')

-- %%
select *
from com_raw.vod_hco
where npi_num__v in ('1356745152',
'1124300256',
'1851634935',
'1457670788',
'1174928139',
'1003825928',
'1205998259',
'1255542817',
'1316277635',
'1043614811',
'1770987810',
'1740688613',
'1780088583',
'1114321981',
'1083019046',
'1588656870',
'1407250202',
'1417258500',
'1699889576')

-- %%
select * from
com_raw.vod_hco
where vid__v in ('242979624307393536')

-- %%
select distinct vid__v, npi_num__v, corporate_name__v, hospital_parent__v, top_parent__v from com_raw.vod_hco
where immediate_parent__v in ('242979624307393536')

-- %%
select vid__v, count(distinct immediate_parent__v) as total_parents
from com_raw.vod_hco
where vid__v in (select distinct vid__v from com_raw.vod_hco
where immediate_parent__v in ('242979624307393536'))
group by vid__v

-- %% [markdown]
-- ### Child to parent mapping

-- %%
with t1 as (select distinct a.vid__v as child_vid, a.npi_num__v as child_npi, a.corporate_name__v as child_name, a.top_parent__v as parent_vid , b.npi_num__v as parent_npi, b.corporate_name__v as parent_name
from com_raw.vod_hco as a
132610', '1124558929', '1447355771', '1154339588', '1548343510', '1144282583', '1164474235', '1407813660', '1447221056', '1043397292', '1437292927', '1811466881', '1063443455', '1003863168', '1568469997', '1053437871', '1205822236', '1487622296', '1407813603', '1417946021', '1013092691', '1013079896', '1114206422', '1538208210', '1194932814', '1255401519', '1942685920', '1013959972', '1043263080', '1043497019', '1871886366', '1306883228', '1902959653', '1497760987', '1841513611', '1013559921', '1740268846', '1952359986', '1265686000', '1033172390', '1003103391', '1316385164', '1073706263', '1376577247', '1487760906', '1457458556', '1497838494', '1437119310', '1730254681', '1285641514', '1306013552', '1811299944', '1063743490', '1295788677', '1346251428', '1376697482', '1396129524', '1245216183', '1013981554', '1861689168', '1396781795', '1073527388', '1801025481', '1043596125', '1306825997', '1548286172', '1801828421', '1386188837', '1427082957', '1780676650', '1407995186', '1740354851', '1548293954', '1336524214', '1477531580', '1174651079', '1275130650', '1609906247', '1700987328', '1295826485', '1255422416', '1700946605', '1023134657', '1255431987', '1740215219', '1053356352', '1184046187', '1013459908', '1710042429', '1003039488', '1629503057', '1578792271', '1306227764', '1356695266', '1033210323', '1285676544', '1184612764', '1023494473', '1871660407', '1073576740', '1164801627', '1982972899', '1558575746', '1841844099', '1790740777', '1003010992', '1588730360', '1487844015', '1437136066', '1366492977', '1487904546', '1538101688', '1477941375', '1609869916', '1013026020', '1366647968', '1811944101', '1295794162', '1609044478', '1124163902', '1265431829', '1861530776', '1235406455', '1851361778', '1194897595', '1114925567', '1407843345', '1114971660', '1538157508', '1174579155', '1942275805', '1871998963', '1003083445', '1497723407', '1386894392', '1013996560', '1003465097', '1063954113', '1447423959', '1952333460', '1710408265', '1043371826', '1699721985', '1255393245', '1154350262', '1871910968', '1407801640', '1245295757', '1720488646', '1144376807', '1134205032', '1831318856', '1104867167', '1104819366', '1023286184', '1821027079', '1528100427', '1033225875', '1386826303', '1083781892', '1073835567', '1114931342', '1083708226', '1396837951', '1194790055', '1063617280', '1437170685', '1609915164', '1831187764', '1952390643', '1689919599', '1417580838', '1114971819', '1578568481', '1295137404', '1235600834', '1215931068', '1588832869', '1710072798', '1811325103', '1003951195', '1912992553', '1134144090', '1306079330', '1194883306', '1780694372', '1164478442', '1336132323', '1043554967', '1629514070', '1760498588', '1841657947', '1255748059', '1386041457', '1639538861', '1265780621'
    )
),
t2 AS (
    SELECT DISTINCT
        vid__v AS parent_vid,
        npi_num__v AS parent_npi,
        corporate_name__v AS parent_name
    FROM com_raw.vod_hco
)
SELECT
    t1.child_vid,
    t1.child_npi,
    t1.child_name,
    t1.parent_vid,
    t2.parent_npi,
    t2.parent_name
FROM t1
LEFT JOIN t2 ON t1.parent_vid = t2.parent_vid
WHERE t1.child_npi IS NOT NULL AND t2.parent_npi IS NOT NULL;

-- %%
select * from com_raw.vod_npi limit 4
