-- %%
select * from com_edp_prd.com_intgr.survey_target

-- %%
select distinct a.account__v, a.account_display_name__v, b.npi__v
from com_edp_prd.com_intgr.survey_target as a
left join com_edp_prd.com_intgr.customer as b on a.account__v = b.id

-- %%
select * from com_edp_prd.com_intgr.customer
