# %%
# %sql
CREATE OR REPLACE TABLE com_edp_prd.cmpa_insights_internal_schema.tableau_wide_view_pt360 AS
SELECT DISTINCT

    -- Patient core
    a.PATIENT_ID,
    a.PATIENT_YOB,
    a.PATIENT_AGE,
    a.PATIENT_GENDER,
    a.patient_state,
    a.incidence_date,
    a.tivi_incidence_date,
    a.tivi_first_incidence_treatment_date,


    -- Diagnosis / Treatment
    a.first_dx_hcp_5yr,
    a.first_dx_all_visit_count_5yr,
    a.first_dx_last_visit_5yr,
    a.tivi_first_dx_hcp_5yr,
    a.tivi_first_dx_all_visit_count_5yr,
    a.tivi_first_dx_last_visit_5yr,
    

    a.first_tx_hcp_5yr,
    a.first_tx_all_visit_count_5yr,
    a.first_tx_last_visit_5yr,
    a.tivi_first_tx_hcp_5yr,
    a.tivi_first_tx_all_visit_count_5yr,
    a.tivi_first_tx_last_visit_5yr,

    -- Most seen HCPs
    a.most_seen_hcp1_3yr_ranked,
    a.most_seen_hcp1_visit_count_5yr,
    a.most_seen_hcp1_last_visit_5yr,
    a.tivi_most_seen_hcp1_3yr_ranked,
    a.tivi_most_seen_hcp1_visit_count_5yr,
    a.tivi_most_seen_hcp1_last_visit_5yr,

    a.most_seen_hcp2_3yr_ranked,
    a.most_seen_hcp2_visit_count_5yr,
    a.most_seen_hcp2_last_visit_5yr,
    a.tivi_most_seen_hcp2_3yr_ranked,
    -- a.tivi_most_seen_hcp2_3yr_ranked, -------- Duplicate
    a.tivi_most_seen_hcp2_visit_count_5yr,
    a.tivi_most_seen_hcp2_last_visit_5yr,

    a.most_seen_hcp3_3yr_ranked,
    a.most_seen_hcp3_visit_count_5yr,
    a.most_seen_hcp3_last_visit_5yr,
    a.tivi_most_seen_hcp3_3yr_ranked,
    a.tivi_most_seen_hcp3_visit_count_5yr,
    a.tivi_most_seen_hcp3_last_visit_5yr,

    a.most_seen_hcp4_3yr_ranked,
    a.most_seen_hcp4_visit_count_5yr,
    a.most_seen_hcp4_last_visit_5yr,
    a.tivi_most_seen_hcp4_3yr_ranked,
    a.tivi_most_seen_hcp4_visit_count_5yr,
    a.tivi_most_seen_hcp4_last_visit_5yr,

    a.most_seen_hcp5_3yr_ranked,
    a.most_seen_hcp5_visit_count_5yr,
    a.most_seen_hcp5_last_visit_5yr,
    a.tivi_most_seen_hcp5_3yr_ranked,
    a.tivi_most_seen_hcp5_visit_count_5yr,
    a.tivi_most_seen_hcp5_last_visit_5yr,

    -- Latest treatment / claim
    a.latest_treatment_date,
    a.latest_treatment_hcp_npi,
    a.latest_treatment_hcp_name,
    a.latest_treatment_hcp_specialty,
    a.latest_treatment_hcp_visit_count,
    a.latest_treatment_hcp_hco_name,
    a.tivi_latest_treatment_date,
    a.tivi_latest_treatment_hcp_npi,
    a.tivi_latest_treatment_hcp_name,
    a.tivi_latest_treatment_hcp_specialty,
    a.tivi_latest_treatment_hcp_visit_count,
    a.tivi_latest_treatment_hcp_hco_name,

    a.latest_claim_date,
    a.latest_claim_hcp_npi,
    a.latest_claim_hcp_name,
    a.latest_claim_hcp_specialty,
    a.latest_claim_hcp_visit_count,
    --a.latest_claim_hcp_hco_npi,
    a.latest_claim_hcp_hco_name,
    a.tivi_latest_claim_date,
    a.tivi_latest_claim_hcp_npi,
    a.tivi_latest_claim_hcp_name,
    a.tivi_latest_claim_hcp_specialty,
    a.tivi_latest_claim_hcp_visit_count,
    a.tivi_latest_claim_hcp_hco_name,

    -- Recent treatment
    a.most_recently_treated_hcp_2yr,
    a.most_recently_treated_hcp_name_2yr,
    a.most_recently_treated_hcp_specialty_2yr,
    a.most_recently_treated_hcp_2yr_no_of_visits_5yr,
    a.most_recent_tx_hcp_2yr_last_visit_5yr,
    a.most_recently_treated_hcp_hco_name,
    a.most_recently_treated_hcp_region_id_2yr,
    a.most_recently_treated_hcp_region_2yr,
    a.tivi_most_recently_treated_hcp_2yr,
    a.tivi_most_recently_treated_hcp_name_2yr,
    
    a.tivi_most_recently_treated_hcp_2yr_no_of_visits_5yr,
    a.tivi_most_recent_tx_hcp_2yr_last_visit_5yr,
    a.tivi_most_recently_treated_hcp_hco_name,
    a.tivi_most_recently_treated_hcp_region_id_2yr,
    a.tivi_most_recently_treated_hcp_region_2yr,
    a.tivi_most_recently_treated_hcp_specialty_2yr,

    -- Primary HCP
    a.PRIMARY_HCP_NPI,
    a.NO_OF_VISITS,
    a.MOST_RECENT_VISIT,
    CASE 
    WHEN a.primary_hcp_name_2yr IS NULL 
         OR TRIM(a.primary_hcp_name_2yr) = '' 
         OR a.primary_hcp_name_2yr = '-' 
    THEN 'Unknown'
    ELSE a.primary_hcp_name_2yr
    END AS primary_hcp_name_2yr,
    a.primary_hcp_specialty,
    CASE 
    WHEN a.primary_hcp_hco_name_2yr IS NULL 
         OR TRIM(a.primary_hcp_hco_name_2yr) = '' 
         OR a.primary_hcp_hco_name_2yr = '-' 
    THEN 'Unknown'
    ELSE a.primary_hcp_hco_name_2yr
    END AS primary_hcp_hco_name_2yr,
    CAST(a.primary_hcp_region_id_2yr AS STRING) AS primary_hcp_region_id_2yr,
    a.primary_hcp_region_2yr,
    ---a.tivi_PRIMARY_HCP_NPI,
    ---a.tivi_NO_OF_VISITS,
    ---a.tivi_MOST_RECENT_VISIT,
    ---a.tivi_primary_hcp_name_2yr,
    ---a.tivi_primary_hcp_hco_name_2yr,
    ---CAST(a.tivi_rimary_hcp_region_id_2yr AS STRING) AS primary_hcp_region_id_2yr,
    ---a.tivi_primary_hcp_region_2yr,

    -- Clinical
    a.severity,
    a.comorbidity_categories,
    a.count_of_comorbidity_categories,
    a.distinct_comorbidities,
    a.count_of_distinct_comorbidities,
    a.first_tx_after_diagnosis,
    a.latest_mpsii_tx_type,
    a.most_recent_infusion_description,
    -- Payer
    a.primary_payer,
    a.secondary_payer,

    -- Territory handling (only here)
    CASE
        WHEN CAST(a.primary_hcp_territory_id_2yr AS STRING) IS NULL
          OR TRIM(CAST(a.primary_hcp_territory_id_2yr AS STRING)) = ' '
        THEN 'Unknown'
        ELSE CAST(a.primary_hcp_territory_id_2yr AS STRING)
    END AS primary_hcp_territory_id_2yr,

    CASE
        WHEN a.primary_hcp_territory_2yr IS NULL
          OR a.primary_hcp_territory_2yr = ' '
        THEN 'Unknown'
        ELSE a.primary_hcp_territory_2yr
    END AS primary_hcp_territory_2yr,

    -- Enriched HCP Elparase details
    CONCAT(b1_spec.FIRST_NAME, ' ', b1_spec.LAST_NAME) AS most_seen_hcp1_name_3yr,
    b1.hco_name AS most_seen_hco1_name_3yr,
    b1_spec.PRIMARY_SPECIALTY AS most_seen_hcp1_specialty,

    CONCAT(b2_spec.FIRST_NAME, ' ', b2_spec.LAST_NAME) AS most_seen_hcp2_name_3yr,
    b2.hco_name AS most_seen_hco2_name_3yr,
    b2_spec.PRIMARY_SPECIALTY AS most_seen_hcp2_specialty,

    CONCAT(b3_spec.FIRST_NAME, ' ', b3_spec.LAST_NAME) AS most_seen_hcp3_name_3yr,
    b3.hco_name AS most_seen_hco3_name_3yr,
    b3_spec.PRIMARY_SPECIALTY AS most_seen_hcp3_specialty,

    CONCAT(b4_spec.FIRST_NAME, ' ', b4_spec.LAST_NAME) AS most_seen_hcp4_name_3yr,
    b4.hco_name AS most_seen_hco4_name_3yr,
    b4_spec.PRIMARY_SPECIALTY AS most_seen_hcp4_specialty,

    CONCAT(b5_spec.FIRST_NAME, ' ', b5_spec.LAST_NAME) AS most_seen_hcp5_name_3yr,
    b5.hco_name AS most_seen_hco5_name_3yr,
    b5_spec.PRIMARY_SPECIALTY AS most_seen_hcp5_specialty,

    CONCAT(b6_spec.FIRST_NAME, ' ', b6_spec.LAST_NAME) AS first_dx_hcp_name_5yr,
    b6.hco_name AS first_dx_hco_name_5yr,
    b6_spec.PRIMARY_SPECIALTY AS first_dx_hcp_specialty,

    CONCAT(b7_spec.FIRST_NAME, ' ', b7_spec.LAST_NAME) AS first_tx_hcp_name_5yr,
    b7.hco_name AS first_tx_hco_name_5yr,
    b7_spec.PRIMARY_SPECIALTY AS first_tx_hcp_specialty,


    -- Enriched HCP Tivi details
    CONCAT(t1_spec.FIRST_NAME, ' ', t1_spec.LAST_NAME) AS tivi_most_seen_hcp1_name_3yr,
    t1.hco_name AS tivi_most_seen_hco1_name_3yr,
    t1_spec.PRIMARY_SPECIALTY AS tivi_most_seen_hcp1_specialty,

    CONCAT(t2_spec.FIRST_NAME, ' ', t2_spec.LAST_NAME) AS tivi_most_seen_hcp2_name_3yr,
    t2.hco_name AS tivi_most_seen_hco2_name_3yr,
    t2_spec.PRIMARY_SPECIALTY AS tivi_most_seen_hcp2_specialty,

    CONCAT(t3_spec.FIRST_NAME, ' ', t3_spec.LAST_NAME) AS tivi_most_seen_hcp3_name_3yr,
    t3.hco_name AS tivi_most_seen_hco3_name_3yr,
    t3_spec.PRIMARY_SPECIALTY AS tivi_most_seen_hcp3_specialty,

    CONCAT(t4_spec.FIRST_NAME, ' ', t4_spec.LAST_NAME) AS tivi_most_seen_hcp4_name_3yr,
    t4.hco_name AS tivi_most_seen_hco4_name_3yr,
    t4_spec.PRIMARY_SPECIALTY AS tivi_most_seen_hcp4_specialty,

    CONCAT(t5_spec.FIRST_NAME, ' ', t5_spec.LAST_NAME) AS tivi_most_seen_hcp5_name_3yr,
    t5.hco_name AS tivi_most_seen_hco5_name_3yr,
    t5_spec.PRIMARY_SPECIALTY AS tivi_most_seen_hcp5_specialty,

    CONCAT(t6_spec.FIRST_NAME, ' ', t6_spec.LAST_NAME) AS tivi_first_dx_hcp_name_5yr,
    t6.hco_name AS tivi_first_dx_hco_name_5yr,
    t6_spec.PRIMARY_SPECIALTY AS tivi_first_dx_hcp_specialty,

    CONCAT(t7_spec.FIRST_NAME, ' ', t7_spec.LAST_NAME) AS tivi_first_tx_hcp_name_5yr,
    t7.hco_name AS tivi_first_tx_hco_name_5yr,
    t7_spec.PRIMARY_SPECIALTY AS tivi_first_tx_hcp_specialty


FROM com_edp_prd.cmpa_insights_internal_schema.patient360_master a

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b1
    ON a.most_seen_hcp1_3yr_ranked = b1.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b1_spec
    ON a.most_seen_hcp1_3yr_ranked = b1_spec.npi
   AND b1_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b2
    ON a.most_seen_hcp2_3yr_ranked = b2.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b2_spec
    ON a.most_seen_hcp2_3yr_ranked = b2_spec.npi
   AND b2_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b3
    ON a.most_seen_hcp3_3yr_ranked = b3.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b3_spec
    ON a.most_seen_hcp3_3yr_ranked = b3_spec.npi
   AND b3_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b4
    ON a.most_seen_hcp4_3yr_ranked = b4.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b4_spec
    ON a.most_seen_hcp4_3yr_ranked = b4_spec.npi
   AND b4_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b5
    ON a.most_seen_hcp5_3yr_ranked = b5.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b5_spec
    ON a.most_seen_hcp5_3yr_ranked = b5_spec.npi
   AND b5_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b6
    ON a.first_dx_hcp_5yr = b6.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b6_spec
    ON a.first_dx_hcp_5yr = b6_spec.npi
   AND b6_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file b7
    ON a.first_tx_hcp_5yr = b7.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers b7_spec
    ON a.first_tx_hcp_5yr = b7_spec.npi
   AND b7_spec.PROVIDER_TYPE = 'INDIVIDUAL'

-----tivi
LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t1
    ON a.tivi_most_seen_hcp1_3yr_ranked = t1.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t1_spec
    ON a.tivi_most_seen_hcp1_3yr_ranked = t1_spec.npi
   AND t1_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t2
    ON a.tivi_most_seen_hcp2_3yr_ranked = t2.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t2_spec
    ON a.tivi_most_seen_hcp2_3yr_ranked = t2_spec.npi
   AND t2_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t3
    ON a.tivi_most_seen_hcp3_3yr_ranked = t3.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t3_spec
    ON a.tivi_most_seen_hcp3_3yr_ranked = t3_spec.npi
   AND t3_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t4
    ON a.tivi_most_seen_hcp4_3yr_ranked = t4.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t4_spec
    ON a.tivi_most_seen_hcp4_3yr_ranked = t4_spec.npi
   AND t4_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t5
    ON a.tivi_most_seen_hcp5_3yr_ranked = t5.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t5_spec
    ON a.tivi_most_seen_hcp5_3yr_ranked = t5_spec.npi
   AND t5_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t6
    ON a.tivi_first_dx_hcp_5yr = t6.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t6_spec
    ON a.tivi_first_dx_hcp_5yr = t6_spec.npi
   AND t6_spec.PROVIDER_TYPE = 'INDIVIDUAL'

LEFT JOIN com_edp_prd.cmpa_insights_internal_schema.reference_file t7
    ON a.tivi_first_tx_hcp_5yr = t7.hcp_npi
LEFT JOIN com_edp_prd.com_raw.kom_providers t7_spec
    ON a.tivi_first_tx_hcp_5yr = t7_spec.npi
   AND t7_spec.PROVIDER_TYPE = 'INDIVIDUAL';

# %%
# %sql

-------------------------------------Tivi updated

CREATE OR REPLACE TABLE com_edp_prd.cmpa_insights_internal_schema.tableau_long_view_pt360 AS

WITH base AS (
  SELECT
    -- Keys / filter-driving dims
    patient_id,
    primary_hcp_territory_2yr as territory_name,
    primary_hcp_territory_id_2yr as territory_id,
    primary_hcp_region_2yr as region_name,
    primary_hcp_region_id_2yr as region_id,
    primary_hcp_npi, -- your chosen definition of "primary HCP"
    primary_hcp_name_2yr,
    primary_hcp_hco_name_2yr,
    PRIMARY_HCP_SPECIALTY,
    NO_OF_VISITS,
    MOST_RECENT_VISIT,
    --tivi_primary_hcp_npi, -- your chosen definition of "primary HCP"
    --tivi_primary_hcp_name_2yr,
    --tivi_PRIMARY_HCP_SPECIALTY,
    --tivi_NO_OF_VISITS,
    --tivi_MOST_RECENT_VISIT,
    -- First Diagnosis (5yr)
    first_dx_hcp_5yr, -- add for filtering
    first_dx_hcp_name_5yr,
    first_dx_hco_name_5yr,
    first_dx_hcp_specialty,
    first_dx_all_visit_count_5yr,
    first_dx_last_visit_5yr,
    tivi_first_dx_hcp_5yr, -- add for filtering
    tivi_first_dx_hcp_name_5yr,
    tivi_first_dx_hco_name_5yr,
    tivi_first_dx_hcp_specialty,
    tivi_first_dx_all_visit_count_5yr,
    tivi_first_dx_last_visit_5yr,
    -- First Treatment (5yr)
    first_tx_hcp_5yr, -- add for filtering
    first_tx_hcp_name_5yr,
    first_tx_hco_name_5yr,
    first_tx_hcp_specialty,
    first_tx_all_visit_count_5yr,
    first_tx_last_visit_5yr,
    tivi_first_tx_hcp_5yr, -- add for filtering
    tivi_first_tx_hcp_name_5yr,
    tivi_first_tx_hco_name_5yr,
    tivi_first_tx_hcp_specialty,
    tivi_first_tx_all_visit_count_5yr,
    tivi_first_tx_last_visit_5yr,

    -- Most seen HCPs (3yr)
    most_seen_hcp1_3yr_ranked, -- add for filtering
    most_seen_hcp1_name_3yr,
    most_seen_hcp1_specialty,
    most_seen_hco1_name_3yr,
    most_seen_hcp1_visit_count_5yr,
    most_seen_hcp1_last_visit_5yr,
    tivi_most_seen_hcp1_3yr_ranked, -- add for filtering
    tivi_most_seen_hcp1_name_3yr,
    tivi_most_seen_hcp1_specialty,
    tivi_most_seen_hco1_name_3yr,
    tivi_most_seen_hcp1_visit_count_5yr,
    tivi_most_seen_hcp1_last_visit_5yr,
    most_seen_hcp2_3yr_ranked, -- add for filtering
    most_seen_hcp2_name_3yr,
    most_seen_hcp2_specialty,
    most_seen_hco2_name_3yr,
    most_seen_hcp2_visit_count_5yr,
    most_seen_hcp2_last_visit_5yr,
    tivi_most_seen_hcp2_3yr_ranked, -- add for filtering
    tivi_most_seen_hcp2_name_3yr,
    tivi_most_seen_hcp2_specialty,
    tivi_most_seen_hco2_name_3yr,
    tivi_most_seen_hcp2_visit_count_5yr, --column WAS not in wide_view
    tivi_most_seen_hcp2_last_visit_5yr,
    most_seen_hcp3_3yr_ranked, -- add for filtering
    most_seen_hcp3_name_3yr,
    most_seen_hcp3_specialty,
    most_seen_hco3_name_3yr,
    most_seen_hcp3_visit_count_5yr,
    most_seen_hcp3_last_visit_5yr,
    tivi_most_seen_hcp3_3yr_ranked, -- add for filtering
    tivi_most_seen_hcp3_name_3yr,
    tivi_most_seen_hcp3_specialty,
    tivi_most_seen_hco3_name_3yr,
    tivi_most_seen_hcp3_visit_count_5yr,
    tivi_most_seen_hcp3_last_visit_5yr,
    most_seen_hcp4_3yr_ranked, -- add for filtering
    most_seen_hcp4_name_3yr,
    most_seen_hcp4_specialty,
    most_seen_hco4_name_3yr,
    most_seen_hcp4_visit_count_5yr,
    most_seen_hcp4_last_visit_5yr,
    tivi_most_seen_hcp4_3yr_ranked, -- add for filtering
    tivi_most_seen_hcp4_name_3yr,
    tivi_most_seen_hcp4_specialty,
    tivi_most_seen_hco4_name_3yr,
    tivi_most_seen_hcp4_visit_count_5yr,
    tivi_most_seen_hcp4_last_visit_5yr,
    most_seen_hcp5_3yr_ranked, -- add for filtering
    most_seen_hcp5_name_3yr,
    most_seen_hcp5_specialty,
    most_seen_hco5_name_3yr,
    most_seen_hcp5_visit_count_5yr,
    most_seen_hcp5_last_visit_5yr,
    tivi_most_seen_hcp5_3yr_ranked, -- add for filtering
    tivi_most_seen_hcp5_name_3yr,
    tivi_most_seen_hcp5_specialty,
    tivi_most_seen_hco5_name_3yr,
    tivi_most_seen_hcp5_visit_count_5yr,
    tivi_most_seen_hcp5_last_visit_5yr,
    most_recently_treated_hcp_2yr,
    most_recently_treated_hcp_name_2yr,
    most_recently_treated_hcp_specialty_2yr,
    most_recently_treated_hcp_2yr_no_of_visits_5yr,
    most_recently_treated_hcp_hco_name,
    most_recent_tx_hcp_2yr_last_visit_5yr,
    tivi_most_recently_treated_hcp_2yr,
    tivi_most_recently_treated_hcp_name_2yr,
    tivi_most_recently_treated_hcp_2yr_no_of_visits_5yr,
    tivi_most_recently_treated_hcp_hco_name,
    tivi_most_recent_tx_hcp_2yr_last_visit_5yr,
    tivi_most_recently_treated_hcp_specialty_2yr,
    latest_treatment_date,
    latest_treatment_hcp_npi,
    latest_treatment_hcp_name,
    latest_treatment_hcp_specialty, 
    latest_treatment_hcp_visit_count,
    latest_treatment_hcp_hco_name,
    tivi_latest_treatment_date,
    tivi_latest_treatment_hcp_npi,
    tivi_latest_treatment_hcp_name,
    tivi_latest_treatment_hcp_specialty, 
    tivi_latest_treatment_hcp_visit_count,
    tivi_latest_treatment_hcp_hco_name,
    latest_claim_date,
    latest_claim_hcp_npi, 
    latest_claim_hcp_name,
    latest_claim_hcp_specialty,
    latest_claim_hcp_visit_count,
    latest_claim_hcp_hco_name,
    tivi_latest_claim_date,
    tivi_latest_claim_hcp_npi, 
    tivi_latest_claim_hcp_name,
    tivi_latest_claim_hcp_specialty,
    tivi_latest_claim_hcp_visit_count,
    tivi_latest_claim_hcp_hco_name

 
FROM
    com_edp_prd.cmpa_insights_internal_schema.tableau_wide_view_pt360
)

SELECT
  patient_id,
  territory_name AS territory,
  region_name,
  region_id,
  territory_id,
  primary_hcp_hco_name_2yr,
  primary_hcp_npi,
  primary_hcp_name_2yr,
  COALESCE(CAST(hco_name AS STRING), '-') AS hco_name,
  COALESCE(CAST(hcp_name AS STRING), '-') AS hcp_name,
  COALESCE(CAST(hcp_specialty AS STRING), '-') AS hcp_specialty,
  COALESCE(CAST(all_visit_count_5yr AS STRING), '-') AS all_visit_count_5yr,
  recordtype,
  treatment_type,
  COALESCE(date_format(lastvisit, 'M/d/yyyy'), '-') AS lastvisit

FROM (

-- =========================
-- ✅ FIRST DX
-- =========================
SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  first_dx_hcp_name_5yr AS hcp_name,
  first_dx_hco_name_5yr AS hco_name,
  first_dx_hcp_specialty AS hcp_specialty,
  'First Dx HCP (5yr)' AS recordtype,
  first_dx_all_visit_count_5yr AS all_visit_count_5yr,
  first_dx_last_visit_5yr AS lastvisit,
  'Elaprase' AS treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_first_dx_hcp_name_5yr AS hcp_name,
  tivi_first_dx_hco_name_5yr as hco_name,
  tivi_first_dx_hcp_specialty as hcp_specialty,
  'First Dx HCP (5yr)' as recordtype,
  tivi_first_dx_all_visit_count_5yr as all_visit_count_5yr,
  tivi_first_dx_last_visit_5yr as lastvisit,
  'AVLAYAH' as treatment_type
FROM base


-- =========================
-- ✅ FIRST TX
-- =========================
UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  first_tx_hcp_name_5yr as hcp_name,
  first_tx_hco_name_5yr as hco_name,
  first_tx_hcp_specialty as hcp_specialty,
  'First Tx HCP (5yr)' as recordtype,
  first_tx_all_visit_count_5yr as all_visit_count_5yr,
  first_tx_last_visit_5yr as lastvisit,
  'Elaprase' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_first_tx_hcp_name_5yr as hcp_name,
  tivi_first_tx_hco_name_5yr as hco_name,
  tivi_first_tx_hcp_specialty as hcp_specialty,
  'First Tx HCP (5yr)' as recordtype,
  tivi_first_tx_all_visit_count_5yr as all_visit_count_5yr,
  tivi_first_tx_last_visit_5yr as lastvisit,
  'AVLAYAH' as treatment_type
FROM base


-- =========================
-- ✅ MOST SEEN HCP (1 example, repeat for 2–5)
-- =========================
UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  most_seen_hcp1_name_3yr AS hcp_name,
  most_seen_hco1_name_3yr as hco_name,
  most_seen_hcp1_specialty as hcp_speciatly,
  'Most seen HCP1 (3yr)' as recordtype,
  most_seen_hcp1_visit_count_5yr as all_visit_count_5yr,
  most_seen_hcp1_last_visit_5yr as last_visit,
  'Elaprase' as treatment_type
FROM base


UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_most_seen_hcp1_name_3yr as hcp_name,
  tivi_most_seen_hco1_name_3yr as hco_name,
  tivi_most_seen_hcp1_specialty as hcp_specialty,
  'Most seen HCP1 (3yr)' as recordtype,
  tivi_most_seen_hcp1_visit_count_5yr as all_visit_count_5yr,
  tivi_most_seen_hcp1_last_visit_5yr as last_visit,
  'AVLAYAH' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_most_seen_hcp2_name_3yr AS hcp_name,
  tivi_most_seen_hco2_name_3yr as hco_name,
  tivi_most_seen_hcp2_specialty as hcp_specialty,
  'Most seen HCP2 (3yr)' as recordtype,
  tivi_most_seen_hcp2_visit_count_5yr as all_visit_count_5yr, -- column WAS missing in base 
  tivi_most_seen_hcp2_last_visit_5yr as last_visit,
  'AVLAYAH' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  most_seen_hcp2_name_3yr as hcp_name,
  most_seen_hco2_name_3yr as hco_name,
  most_seen_hcp2_specialty as hcp_specialty,
  'Most seen HCP2 (3yr)' as recordtype,
  most_seen_hcp2_visit_count_5yr as all_visit_count_5yr,
  most_seen_hcp2_last_visit_5yr as last_visit,
  'Elaprase' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_most_seen_hcp3_name_3yr as hcp_name,
  tivi_most_seen_hco3_name_3yr as hco_name,
  tivi_most_seen_hcp3_specialty as hcp_specialty,
  'Most seen HCP3 (3yr)' as recordtype,
  tivi_most_seen_hcp3_visit_count_5yr as all_visit_count_5yr,
  tivi_most_seen_hcp3_last_visit_5yr as last_visit,
  'AVLAYAH' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  most_seen_hcp3_name_3yr AS hcp_name,
  most_seen_hco3_name_3yr as hco_name,
  most_seen_hcp3_specialty as hcp_specialty,
  'Most seen HCP3 (3yr)' as recordtype,
  most_seen_hcp3_visit_count_5yr as all_visit_count_5yr,
  most_seen_hcp3_last_visit_5yr as last_visit,
  'Elaprase' as treatment_type
FROM base


UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_most_seen_hcp4_name_3yr as hcp_name,
  tivi_most_seen_hco4_name_3yr as hco_name,
  tivi_most_seen_hcp4_specialty as hcp_specialty,
  'Most seen HCP4 (3yr)' as recordtype,
  tivi_most_seen_hcp4_visit_count_5yr as all_visit_count_5yr,
  tivi_most_seen_hcp4_last_visit_5yr as last_visit,
  'AVLAYAH' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  most_seen_hcp4_name_3yr as hcp_name,
  most_seen_hco4_name_3yr as hco_name,
  most_seen_hcp4_specialty as hcp_specialty,
  'Most seen HCP4 (3yr)' as recordtype,
  most_seen_hcp4_visit_count_5yr as all_visit_count_5yr,
  most_seen_hcp4_last_visit_5yr as last_visit,
  'Elaprase' as treatment_type
FROM base


UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_most_seen_hcp5_name_3yr as hcp_visit,
  tivi_most_seen_hco5_name_3yr as hco_visit,
  tivi_most_seen_hcp5_specialty as hcp_specialty,
  'Most seen HCP5 (3yr)' as recordtype,
  tivi_most_seen_hcp5_visit_count_5yr as all_visit_count_5yr,
  tivi_most_seen_hcp5_last_visit_5yr as last_visit,
  'AVLAYAH' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  most_seen_hcp5_name_3yr as hcp_visit,
  most_seen_hco5_name_3yr as hco_visit,
  most_seen_hcp5_specialty as hcp_specialty,
  'Most seen HCP5 (3yr)' as recordtype,
  most_seen_hcp5_visit_count_5yr as all_visit_count_5yr,
  most_seen_hcp5_last_visit_5yr as last_visit,
  'Elaprase' as treatment_type
FROM base



-- =========================
-- ✅ PRIMARY HCP
-- =========================
UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  primary_hcp_name_2yr as hcp_name,
  primary_hcp_hco_name_2yr as hco_name,
  primary_hcp_specialty as hcp_specialty,
  'Primary HCP (2yr)' as recordtype,
  no_of_visits as all_visit_count_5yr,
  most_recent_visit as last_visit,
  'Elaprase' as treatment_type
FROM base

/*-------------UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_primary_hcp_name_2yr,
  tivi_primary_hcp_name_2yr,
  tivi_primary_hcp_specialty,
  'Primary HCP (2yr)',
  tivi_no_of_visits,
  tivi_most_recent_visit,
  'Tivi'
FROM base---------------------*/


-- =========================
-- ✅ MOST RECENTLY TREATED
-- =========================
UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  most_recently_treated_hcp_name_2yr as hcp_name,
  most_recently_treated_hcp_hco_name as hco_name,
  most_recently_treated_hcp_specialty_2yr as hcp_specialty,
  'Most recently treated HCP (2yr)' as recordtype,
  most_recently_treated_hcp_2yr_no_of_visits_5yr as all_visit_count_5yr,
  most_recent_tx_hcp_2yr_last_visit_5yr as last_visit,
  'Elaprase' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_most_recently_treated_hcp_name_2yr as hcp_name,
  tivi_most_recently_treated_hcp_hco_name as hco_name,
  tivi_most_recently_treated_hcp_specialty_2yr as hcp_specialty,
  'Most recently treated HCP (2yr)' as recordtype,
  tivi_most_recently_treated_hcp_2yr_no_of_visits_5yr as all_visit_count_5yr,
  tivi_most_recent_tx_hcp_2yr_last_visit_5yr as last_visit,
  'AVLAYAH' as treatment_type
FROM base


-- =========================
-- ✅ LATEST TREATMENT
-- =========================
UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  latest_treatment_hcp_name as hcp_name,
  latest_treatment_hcp_hco_name as hco_name,
  latest_treatment_hcp_specialty as hcp_specialty,
  'Last Infusion HCP' as recordtype,
  latest_treatment_hcp_visit_count as all_visit_count_5yr,
  latest_treatment_date as last_visit,
  'Elaprase' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_latest_treatment_hcp_name as hcp_name,
  tivi_latest_treatment_hcp_hco_name as hco_name,
  tivi_latest_treatment_hcp_specialty as hcp_specialty,
  'Last Infusion HCP' as recordtype,
  tivi_latest_treatment_hcp_visit_count as all_visit_count_5yr,
  tivi_latest_treatment_date as last_visit,
  'AVLAYAH' as treatment_type
FROM base


-- =========================
-- ✅ LATEST CLAIM
-- =========================
UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  latest_claim_hcp_name as hcp_name,
  latest_claim_hcp_hco_name as hco_name,
  latest_claim_hcp_specialty as hcp_specialty,
  'Last Visited HCP' as recordtype,
  latest_claim_hcp_visit_count as all_visit_count_5yr,
  latest_claim_date as last_visit,
  'Elaprase' as treatment_type
FROM base

UNION ALL

SELECT
  patient_id, territory_name, territory_id, region_name, region_id,
  primary_hcp_hco_name_2yr, primary_hcp_npi, primary_hcp_name_2yr,
  tivi_latest_claim_hcp_name as hcp_name,
  tivi_latest_claim_hcp_hco_name as hco_name,
  tivi_latest_claim_hcp_specialty as hcp_specialty,
  'Last Visited HCP' as recordtype,
  tivi_latest_claim_hcp_visit_count as all_visit_count_5yr,
  tivi_latest_claim_date as last_visit,
  'AVLAYAH' as treatment_type
FROM base

) u;
