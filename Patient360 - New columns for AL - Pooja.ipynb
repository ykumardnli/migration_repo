-- %%
--com_edp_prd.com_consm.vw_rpt_dist_order_dt_qty_shipped
/*
crx_account_id
crx_account_name
order_date
quantity_shipped
return_quantity
ship_to_address_postal_code
*/

--com_edp_prd.cmpa_insights_internal_schema.pos_description
/*
code	
description	
Place of Service Description
*/

--com_edp_prd.com_raw.crx_hcps
/*
HCP Details
*/

--com_edp_prd.cmpa_insights_internal_schema.zip_to_territory_mapping
/*
zipcode	
territory_id	
territory_name	
city	
state	
region_id	
region_name
*/


--com_edp_prd.com_intgr.distribution_sd_shipments
/*
Shared by Ali over email - Integration Layer
crx_shipments_sd_id
crx_account_id
crx_account_name
crx_address_id
ship_to_address_street_1
order_date
order_number
ndc
*/

-- %%
SELECT * FROM com_edp_prd.com_intgr.distribution_sd_shipments;

-- %%
SELECT * FROM com_edp_prd.com_raw.crx_hcps;

-- %%
SELECT * FROM com_edp_prd.cmpa_insights_internal_schema.pos_description;

-- %%
SELECT * FROM com_edp_prd.com_consm.vw_rpt_dist_order_dt_qty_shipped;

-- %%
SELECT * FROM com_edp_prd.cmpa_insights_internal_schema.patient360_master;
