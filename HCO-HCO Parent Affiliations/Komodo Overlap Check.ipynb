where npi in ('1437365186', '1235234535', '1295789907', '1053632463', '1114969169', '1346297843', '1336245828', '1164426896', '1023105400', '1649347469', '1235339227', '1184649345', '1144266024', '1578693321', '1013143213', '1013062769', '1073053757', '1285832634', '1285174649', '1659877280', '1003063280', '1366556227', '1093894131', '1013924372', '1225249865', '1700128592', '1033439732', '1760480503', '1114924834', '1083789630', '1669462420', '1093808040', '1477549756', '1235214834', '1083630073', '1265694442', '1679973364', '1568596765', '1003878539', '1689747552', '1326092404', '1639370059', '1063702785', '1235582925', '1275694184', '1669683512', '1013924182')

-- %%
with t1 as (select distinct npi as hco_npi, ORGANIZATION_NAME as hco_name, PROVIDER_ADDRESS as hco_address, PROVIDER_CITY as hco_city, PROVIDER_STATE as hco_state, PROVIDER_ZIP as hco_zip
from com_raw.kom_providers
where PROVIDER_TYPE = 'ORGANIZATION' and npi in (select distinct hco_npi from com_edp_prd.cmpa_insights_internal_schema.reference_file_0109 where hco_npi != '-'))
select * from t1

-- %%
with t1 as (select distinct npi as hco_npi, ORGANIZATION_NAME as hco_name, PROVIDER_ADDRESS as hco_address, PROVIDER_CITY as hco_city, PROVIDER_STATE as hco_state, PROVIDER_ZIP as hco_zip
from com_raw.kom_providers
where PROVIDER_TYPE = 'ORGANIZATION' and npi in ('1003102781', '1164686879', '1215921457', '1750482022', '1366515488', '1912939703', '1205935012', '1194787218', '1548212988', '1891765178', '1336495910', '1760476659', '1235148594', '1104819366', '1144548322', '1275564098', '1609824010', '1669429577', '1750458485', '1477643690', '1649261462', '1023188851', '1043447253', '1467525790', '1154302727', '1003961251', '1083949382', '1376544320', '1598784555', '1396882205', '1932280666'))
select * from t1

-- %%
com_edp_prd.com_intgr.survey_target
com_edp_prd.com_intgr.survey_question
WITH npi_list AS (
    SELECT '1003102781' AS hco_npi UNION ALL
    SELECT '1164686879' UNION ALL
    SELECT '1215921457' UNION ALL
    SELECT '1750482022' UNION ALL
    SELECT '1366515488' UNION ALL
    SELECT '1912939703' UNION ALL
    SELECT '1205935012' UNION ALL
    SELECT '1194787218' UNION ALL
    SELECT '1548212988' UNION ALL
    SELECT '1891765178' UNION ALL
    SELECT '1336495910' UNION ALL
    SELECT '1760476659' UNION ALL
    SELECT '1235148594' UNION ALL
    SELECT '1104819366' UNION ALL
    SELECT '1144548322' UNION ALL
    SELECT '1275564098' UNION ALL
    SELECT '1609824010' UNION ALL
    SELECT '1669429577' UNION ALL
    SELECT '1750458485' UNION ALL
    SELECT '1477643690' UNION ALL
    SELECT '1649261462' UNION ALL
    SELECT '1023188851' UNION ALL
    SELECT '1043447253' UNION ALL
    SELECT '1467525790' UNION ALL
    SELECT '1154302727' UNION ALL
    SELECT '1003961251' UNION ALL
    SELECT '1083949382' UNION ALL
    SELECT '1376544320' UNION ALL
    SELECT '1598784555' UNION ALL
    SELECT '1396882205' UNION ALL
    SELECT '1932280666'
),

komodo_hco AS (
    SELECT DISTINCT
        npi AS hco_npi,
        ORGANIZATION_NAME AS hco_name,
        PROVIDER_ADDRESS AS hco_address,
        PROVIDER_CITY AS hco_city,
        PROVIDER_STATE AS hco_state,
        PROVIDER_ZIP AS hco_zip
    FROM com_raw.kom_providers
    WHERE PROVIDER_TYPE = 'ORGANIZATION'
)

SELECT
    n.hco_npi,
    k.hco_name,
    k.hco_address,
    k.hco_city,
    k.hco_state,
    k.hco_zip,
    CASE 
        WHEN k.hco_npi IS NULL THEN 0 
        ELSE 1 
    END AS komodo_flag
FROM npi_list n
LEFT JOIN komodo_hco k
    ON n.hco_npi = k.hco_npi;
