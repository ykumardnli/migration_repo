# %%
# %sql
select * from vod_reltio_stage.customer_hco;

# %%
# %sql
SELECT * from vod_reltio_stage.customer_hcp;

# %%
# %sql
select * from vod_reltio_stage.customer_hcp_hco_affiliation;

# %%
# %sql
select * from vod_reltio_stage.customer_location;

# %%
# %sql
select * from vod_reltio_stage.customer_organization_affiliation
limit 15;

# %%
# %sql
select * from vod_reltio_stage.customer_organization_hierarchy
limit 15;
