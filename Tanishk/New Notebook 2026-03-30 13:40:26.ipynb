-- %%
select * from com_edp_prd.com_raw.kom_providers

-- %%
select * from com_edp_prd.com_raw.kom_providers where npi in ('1114969169','1134299522','1295820256','1376544320', '1457615759','1649299827','1700961620','1750458485','1962928341')

-- %%
select * from com_edp_prd.com_raw.vod_hcp where npi_num__v in ('1114969169','1134299522','1295820256','1376544320', '1457615759','1649299827','1700961620','1750458485','1962928341')

-- %%
Select * from com_edp_prd.com_raw.vcrm_call2__v limit 2

-- %%
SELECT DISTINCT
    TRY_CAST(c.npi__v AS STRING) AS npi,
    a.account__v,
    a.zvod_acc_dnli_tivi_patients__c,
    c.dnli_tivi_patients__c
FROM com_edp_prd.com_raw.vcrm_call2__v a
LEFT JOIN com_edp_prd.com_intgr.customer c
    ON a.account__v = c.id
WHERE c.npi__v IS NOT NULL
  -- AND a.zvod_acc_dnli_tivi_patients__c IN (1, 2);
