-- %%
select * from com_edp_prd.cmpa_insights_internal_schema.patient360_master

-- %%
select patient_id, count(distinct primary_hcp_npi) from com_edp_prd.cmpa_insights_internal_schema.patient360_master group by patient_id
